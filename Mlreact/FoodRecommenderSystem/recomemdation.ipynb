# %%
import pandas as pd

# %%
recipes = pd.read_csv('recipes.csv')

# %%
recipes.head(1)
# Out:
#    RecipeId                               Name  AuthorId AuthorName CookTime  \
# 0        38  Low-Fat Berry Blue Frozen Dessert      1533     Dancer    PT24H
#
#   PrepTime TotalTime         DatePublished  \
# 0    PT45M  PT24H45M  1999-08-09T21:46:00Z
#
#                                          Description  \
# 0  Make and share this Low-Fat Berry Blue Frozen ...
#
#                                               Images  ... SaturatedFatContent  \
# 0  c("https://img.sndimg.com/food/image/upload/w_...  ...                 1.3
#
#   CholesterolContent SodiumContent CarbohydrateContent  FiberContent  \
# 0                8.0          29.8                37.1           3.6
#
#    SugarContent  ProteinContent  RecipeServings  RecipeYield  \
# 0          30.2             3.2             4.0          NaN
#
#                                   RecipeInstructions
# 0  c("Toss 2 cups berries with sugar.", "Let stan...
#
# [1 rows x 28 columns]

# %%
recipes.shape
# Out:
# (522517, 28)

# %%
max_Calories=2000
max_daily_fat=100
max_daily_Saturatedfat=13
max_daily_Cholesterol=300
max_daily_Sodium=2300
max_daily_Carbohydrate=325
max_daily_Fiber=40
max_daily_Sugar=40
max_daily_Protein=200
max_list=[max_Calories,max_daily_fat,max_daily_Saturatedfat,max_daily_Cholesterol,max_daily_Sodium,max_daily_Carbohydrate,max_daily_Fiber,max_daily_Sugar,max_daily_Protein]

# %%
min_Calories=500
min_daily_fat=100
min_daily_Saturatedfat=2
min_daily_Cholesterol=100
min_daily_Sodium=300
min_daily_Carbohydrate=100
min_daily_Fiber=4
min_daily_Sugar=4
min_daily_Protein=10
min_list=[max_Calories,max_daily_fat,max_daily_Saturatedfat,max_daily_Cholesterol,max_daily_Sodium,max_daily_Carbohydrate,max_daily_Fiber,max_daily_Sugar,max_daily_Protein]

# %%
recipes = recipes[recipes['Calories']<=max_Calories]

# %%
recipes = recipes[recipes['Calories']<=min_Calories]

# %%
recipes = recipes[recipes['FatContent']<=max_daily_fat]

# %%
recipes = recipes[recipes['FatContent']<=min_daily_fat]

# %%
recipes = recipes[recipes['SaturatedFatContent']<=max_daily_Saturatedfat]

# %%
recipes = recipes[recipes['SaturatedFatContent']<=min_daily_Saturatedfat]

# %%
recipes = recipes[recipes['CholesterolContent']<=max_daily_Cholesterol]

# %%
recipes = recipes[recipes['CholesterolContent']<=min_daily_Cholesterol]

# %%
recipes = recipes[recipes['SodiumContent']<=max_daily_Sodium]

# %%
recipes = recipes[recipes['SodiumContent']<=min_daily_Sodium]

# %%
recipes = recipes[recipes['CarbohydrateContent']<=max_daily_Carbohydrate]

# %%
recipes = recipes[recipes['CarbohydrateContent']<=min_daily_Carbohydrate]

# %%
recipes = recipes[recipes['FiberContent']<=max_daily_Fiber]

# %%
recipes = recipes[recipes['FiberContent']<=min_daily_Fiber]

# %%
recipes = recipes[recipes['SugarContent']<=max_daily_Sugar]

# %%
recipes = recipes[recipes['SugarContent']<=min_daily_Sugar]

# %%
recipes = recipes[recipes['ProteinContent']<=200]

# %%
recipes = recipes[recipes['ProteinContent']<=10]

# %%
recipes = recipes[['Name','Images','Calories','FatContent','SaturatedFatContent','CholesterolContent','SodiumContent','CarbohydrateContent','FiberContent','SugarContent','ProteinContent']]

# %%
recipes.head(30)
# Out:
#                                                   Name  \
# 8                              A Jad - Cucumber Pickle
# 9                                 Butter Pecan Cookies
# 30                                      Chicha Peruana
# 44      Braised Brussels Sprouts With Vinegar and Dill
# 46                                         Butter Dips
# 75                            Carrot & Tahini Sandwich
# 80             Catherine's Excellent Yorkshire Pudding
# 87                                Buttermilk-Oat Bread
# 90                         Cherry Sandwich Maker Snack
# 101                                          Bugwiches
# 102                                       Cheese Rolls
# 136                 Chicken, Mozzarella & Pepper Tarts
# 220                        Ouzo-Marinated Greek Cheese
# 241                                      Apricot Salsa
# 252                                        Florentines
# 267                            Spicy Acorn Squash Soup
# ...

# %%
recipes.loc[:, 'Images'] = recipes['Images'].astype('string')

# %%
recipes['Images'] = recipes['Images'].replace('character(0)','')

# %%
recipes = recipes[recipes['Images'] != '']

# %%
recipes = recipes.dropna()

# %%
import re

# %%
def extract_quoted_strings(s):
    # Find all the strings inside double quotes
    strings = re.findall(r'"([^"]*)"', s)
    # Join the strings with 'and'
    return strings

# %%
recipes['Images'] = recipes['Images'].apply(extract_quoted_strings)

# %%
list = recipes['Images'].head(1)

# %%
user_preferences = {
    'Max_Fat': 10,        # Max fat per serving (grams)
    'Max_Cholesterol': 50, # Max cholesterol per serving (mg)
    'Max_Sugar': 15       # Max sugar per serving (grams)
}

# %%
filtered_df = recipes[
    (recipes['FatContent'] <= user_preferences['Max_Fat']) &
    (recipes['CholesterolContent'] <= user_preferences['Max_Cholesterol']) &
    (recipes['SugarContent'] <= user_preferences['Max_Sugar'])
]

# %%
filtered_df
# Out:
#                                                      Name  \
# 9                                    Butter Pecan Cookies
# 44         Braised Brussels Sprouts With Vinegar and Dill
# 284     Potatoes Tapas in Garlic Mayonnaise (Potatoes ...
# 342                                            Cafe Latte
# 344                                     Frozen Cappuccino
# ...                                                   ...
# 522401                Matcha Oat Milk Latte (Hot or Iced)
# 522402                                   Cold Brew Matcha
# 522456                           SUPER EASY EGGS BENEDICT
# 522489                      Masala Maggi Noodles in a Mug
# 522515           Quick & Easy Asian Cucumber Salmon Rolls
#
#                                                    Images  Calories  \
# 9       [https://img.sndimg.com/food/image/upload/w_55...      69.0
# 44      [https://img.sndimg.com/food/image/upload/w_55...      40.9
# ...

# %%
filtered_df = filtered_df.sort_values(by=['CarbohydrateContent','Calories','ProteinContent'], ascending=[False,False,False])

# %%
filtered_df = filtered_df.sort_values(by='ProteinContent', ascending=False)

# %%
filtered_df = filtered_df.sort_values(by='Calories', ascending=False)

# %%
filtered_df
# Out:
#                                   Name  \
# 155529                         Martini
# 275890             Big Easy Blue Punch
# 359338        Turbo Painkiller Martini
# 195127                X-Rated Vacation
# 282789             Blue Dream Cocktail
# ...                                ...
# 517187  Royal Wedding Doll Cake Recipe
# 517273                 Pool Party Cake
# 517709         Sloppy Hazelnut Pudding
# 517827         Mini Strawberry Falooda
# 522402                Cold Brew Matcha
#
#                                                    Images  Calories  \
# 155529  [https://img.sndimg.com/food/image/upload/w_55...     472.8
# 275890  [https://img.sndimg.com/food/image/upload/w_55...     465.5
# 359338  [https://img.sndimg.com/food/image/upload/w_55...     462.6
# 195127  [https://img.sndimg.com/food/image/upload/w_55...     462.1
# 282789  [https://img.sndimg.com/food/image/upload/w_55...     462.0
# ...                                                   ...       ...
# ...

# %%
filtered_df = filtered_df[filtered_df['Name'] != 'Lavender Scented and Infused Vodka']

# %%
filtered_df = filtered_df[filtered_df['Name'] != 'Lemon Drop Shooters']

# %%
filtered_df = filtered_df[filtered_df['Name'] != 'Easy Homemade Microwave Cleaner']

# %%
filtered_df = filtered_df[filtered_df['Name'] != 'Flubber']

# %%
filtered_df = filtered_df[filtered_df['Name'] != 'Very Cool Koolaid Hair Dye']

# %%
filtered_df = filtered_df[filtered_df['Name'] != 'Soft Scrub']

# %%
filtered_df = filtered_df[filtered_df['Name'] != 'Detox with a Relaxing and Sedative Bath']

# %%
filtered_df = filtered_df[filtered_df['Name'] != 'Dishwasher Soap']

# %%
filtered_df = filtered_df[filtered_df['Name'] != 'Chamomile Hair Shine for Blonde Hair']

# %%
filtered_df = filtered_df[filtered_df['Name'] != 'Homemade Gel Pack']

# %%
filtered_df = filtered_df[filtered_df['Name'] != 'Home Canned Dry Beans']

# %%
import pickle

# %%
pickle.dump(filtered_df,open('recommendmodels.pkl','wb'))
